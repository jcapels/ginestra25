# %%
import pickle


print("Generating new dataset.")
with open(f'char2idx_class_V1.pkl','rb') as f:
    class_  = pickle.load(f)
with open(f'char2idx_super_V1.pkl','rb') as f:
    superclass_  = pickle.load(f)
with open(f'char2idx_path_V1.pkl','rb') as f:
    pathway_  = pickle.load(f)
with open(f'datset_class_all_V1.pkl','rb') as r:
    dataset = pickle.load(r)
    dataset = {k: {k2.replace("_", ""): v2 for k2, v2 in v.items()} for k, v in dataset.items()}
# Out:
# Generating new dataset.

# %%
import numpy as np
import pandas as pd

def dataset_split(matrix, n_samples=None):
    """
    Returns the unique vectors (rows) of a given matrix.

    Parameters:
        matrix (np.ndarray): A 2D numpy array.
        n_samples (int, optional): The number of samples to select from each class. Defaults to config.N_SAMPLES (all the samples if None).

    Returns:
        np.ndarray: A 2D numpy array containing the unique rows of the input matrix.
    """
    if not isinstance(matrix, np.ndarray):
        raise ValueError("Input must be a numpy array.")
    if isinstance(matrix, list):
        print("Input is a list, converting to numpy array.")
        matrix = np.array(matrix)
    if matrix.ndim != 2:
        raise ValueError("Input must be a 2D matrix.")
    
    multilabel = True

    # Search the multi-label samples (if any row has more than one 1)
    if multilabel == True:
        matrix_single_label = matrix
    else:
        sum_rows = np.sum(matrix, axis=1)
        single_label_rows = np.where(sum_rows == 1)[0]
        matrix_single_label = matrix[single_label_rows]
        
    # Find the unique rows
    unique_rows = np.unique(matrix_single_label, axis=0)
    
    # Count the number of occurrences of each unique row
    unique_counts = np.array([np.sum(np.all(matrix_single_label == row, axis=1)) for row in unique_rows])
    
    # Save the indices of matrix containing the unique rows (eg, a list of indices of all the samples of class i)
    classwise_indices = []
    
    # Find the indices of each unique row in the original matrix
    for i, row in enumerate(unique_rows):
        indices = np.where(np.all(matrix_single_label == row, axis=1))[0]
        if len(indices) > 1:
            classwise_indices.append(indices)
            print(f"Row {i} corresponding to class {[m for m in np.where(row==1)[0]]} occurs {len(indices)} times in the original matrix.")
    
    # Equally distribute the samples of each class using the classwise indices
    training_indices = []
    validation_indices = []
    test_indices = []
    
    training_samples = []
    validation_samples = []
    test_samples = []
    
    # Split the indices into training, validation, and test sets
    training_split = 0.6
    validation_split = 0.2  # test_split = 1 - training_split - validation_split
    
    for indices in classwise_indices:
        np.random.shuffle(indices)
        n = len(indices)
        # Update the number of samples if N_SAMPLES is not None
        if n_samples is not None:
            if len(indices) > n_samples:
                print(f"Class {np.argmax(matrix_single_label[indices[0]])} has more than {n_samples} samples. Randomly selecting {n_samples} samples.")
                indices = indices[:n_samples]
                n = n_samples
            else:
                n = len(indices)
                
        train_end = int(training_split * n)
        val_end = int((training_split + validation_split) * n)
        training_indices.extend(indices[:train_end])
        validation_indices.extend(indices[train_end:val_end])
        test_indices.extend(indices[val_end:])
        training_samples.extend(matrix_single_label[indices[:train_end]])
        validation_samples.extend(matrix_single_label[indices[train_end:val_end]])
        test_samples.extend(matrix_single_label[indices[val_end:]])
        print(f"Class {np.argmax(matrix_single_label[indices[0]])} - Training: {len(training_indices)}, Validation: {len(validation_indices)}, Test: {len(test_indices)}")

    training_samples = np.array(training_samples)
    validation_samples = np.array(validation_samples)
    test_samples = np.array(test_samples)
    
    return training_indices, validation_indices, test_indices, training_samples, validation_samples, test_samples



dataset = {k: v for k, v in dataset.items() if np.sum(v["class".capitalize()]) == 1}
smiles_df = [dataset[i]['SMILES'] for i in dataset.keys()]
labels_list = [dataset[i]["class".capitalize()] for i in dataset.keys()]

df = pd.DataFrame({'SMILES': smiles_df, "class".capitalize(): labels_list})
df = df.sample(frac=1, random_state=42).reset_index(drop=True)
train_indices, val_indices, test_indices, _, _, _ = dataset_split(np.array(labels_list))

train_df = df.iloc[train_indices]
val_df = df.iloc[val_indices]
test_df = df.iloc[test_indices]
train_df.to_csv(f'train_smiles.csv', index=False)
val_df.to_csv(f'val_smiles.csv', index=False)
test_df.to_csv(f'test_smiles.csv', index=False)
# Out:
# Row 0 corresponding to class [652] occurs 130 times in the original matrix.
# Row 1 corresponding to class [651] occurs 7 times in the original matrix.
# Row 2 corresponding to class [650] occurs 25 times in the original matrix.
# Row 3 corresponding to class [649] occurs 69 times in the original matrix.
# Row 4 corresponding to class [648] occurs 50 times in the original matrix.
# Row 5 corresponding to class [647] occurs 35 times in the original matrix.
# Row 6 corresponding to class [646] occurs 35 times in the original matrix.
# Row 7 corresponding to class [645] occurs 811 times in the original matrix.
# Row 8 corresponding to class [644] occurs 5 times in the original matrix.
# Row 9 corresponding to class [643] occurs 440 times in the original matrix.
# Row 10 corresponding to class [642] occurs 26 times in the original matrix.
# Row 11 corresponding to class [641] occurs 10 times in the original matrix.
# Row 12 corresponding to class [640] occurs 13 times in the original matrix.
# Row 13 corresponding to class [639] occurs 53 times in the original matrix.
# Row 14 corresponding to class [638] occurs 26 times in the original matrix.
# Row 15 corresponding to class [637] occurs 276 times in the original matrix.
# Row 16 corresponding to class [636] occurs 21 times in the original matrix.
# Row 17 corresponding to class [635] occurs 18 times in the original matrix.
# Row 18 corresponding to class [634] occurs 13 times in the original matrix.
# Row 19 corresponding to class [633] occurs 155 times in the original matrix.
# Row 20 corresponding to class [632] occurs 768 times in the original matrix.
# Row 21 corresponding to class [631] occurs 57 times in the original matrix.
# Row 22 corresponding to class [630] occurs 15 times in the original matrix.
# Row 23 corresponding to class [629] occurs 31 times in the original matrix.
# Row 24 corresponding to class [628] occurs 230 times in the original matrix.
# Row 25 corresponding to class [627] occurs 174 times in the original matrix.
# Row 26 corresponding to class [626] occurs 39 times in the original matrix.
# Row 27 corresponding to class [624] occurs 25 times in the original matrix.
# Row 28 corresponding to class [623] occurs 171 times in the original matrix.
# Row 29 corresponding to class [622] occurs 6889 times in the original matrix.
# Row 30 corresponding to class [621] occurs 42 times in the original matrix.
# Row 31 corresponding to class [620] occurs 60 times in the original matrix.
# Row 32 corresponding to class [619] occurs 44 times in the original matrix.
# Row 33 corresponding to class [618] occurs 56 times in the original matrix.
# Row 34 corresponding to class [617] occurs 21 times in the original matrix.
# Row 35 corresponding to class [616] occurs 59 times in the original matrix.
# Row 36 corresponding to class [615] occurs 11 times in the original matrix.
# Row 37 corresponding to class [613] occurs 4 times in the original matrix.
# Row 38 corresponding to class [612] occurs 16 times in the original matrix.
# Row 39 corresponding to class [611] occurs 24 times in the original matrix.
# Row 40 corresponding to class [609] occurs 67 times in the original matrix.
# Row 41 corresponding to class [608] occurs 116 times in the original matrix.
# Row 42 corresponding to class [607] occurs 59 times in the original matrix.
# Row 43 corresponding to class [606] occurs 4 times in the original matrix.
# Row 44 corresponding to class [604] occurs 100 times in the original matrix.
# Row 45 corresponding to class [603] occurs 83 times in the original matrix.
# Row 46 corresponding to class [601] occurs 122 times in the original matrix.
# Row 47 corresponding to class [600] occurs 23 times in the original matrix.
# Row 48 corresponding to class [599] occurs 13 times in the original matrix.
# Row 49 corresponding to class [597] occurs 38 times in the original matrix.
# Row 50 corresponding to class [596] occurs 6 times in the original matrix.
# Row 51 corresponding to class [595] occurs 137 times in the original matrix.
# Row 52 corresponding to class [594] occurs 13 times in the original matrix.
# Row 53 corresponding to class [593] occurs 13 times in the original matrix.
# Row 54 corresponding to class [591] occurs 111 times in the original matrix.
# Row 55 corresponding to class [590] occurs 31 times in the original matrix.
# Row 56 corresponding to class [589] occurs 101 times in the original matrix.
# Row 57 corresponding to class [588] occurs 48 times in the original matrix.
# Row 58 corresponding to class [587] occurs 81 times in the original matrix.
# Row 59 corresponding to class [586] occurs 105 times in the original matrix.
# Row 60 corresponding to class [585] occurs 70 times in the original matrix.
# Row 61 corresponding to class [584] occurs 24 times in the original matrix.
# Row 62 corresponding to class [583] occurs 67 times in the original matrix.
# Row 63 corresponding to class [582] occurs 20 times in the original matrix.
# Row 64 corresponding to class [581] occurs 6 times in the original matrix.
# Row 65 corresponding to class [580] occurs 24 times in the original matrix.
# Row 66 corresponding to class [579] occurs 83 times in the original matrix.
# Row 67 corresponding to class [578] occurs 4 times in the original matrix.
# Row 68 corresponding to class [577] occurs 9 times in the original matrix.
# Row 69 corresponding to class [576] occurs 158 times in the original matrix.
# Row 70 corresponding to class [575] occurs 15 times in the original matrix.
# Row 71 corresponding to class [574] occurs 110 times in the original matrix.
# Row 72 corresponding to class [572] occurs 57 times in the original matrix.
# Row 73 corresponding to class [571] occurs 526 times in the original matrix.
# Row 74 corresponding to class [570] occurs 46 times in the original matrix.
# Row 75 corresponding to class [569] occurs 21 times in the original matrix.
# Row 76 corresponding to class [568] occurs 28 times in the original matrix.
# Row 77 corresponding to class [567] occurs 20 times in the original matrix.
# Row 78 corresponding to class [566] occurs 16 times in the original matrix.
# Row 79 corresponding to class [565] occurs 81 times in the original matrix.
# Row 80 corresponding to class [564] occurs 50 times in the original matrix.
# Row 81 corresponding to class [563] occurs 42 times in the original matrix.
# Row 82 corresponding to class [562] occurs 14 times in the original matrix.
# Row 83 corresponding to class [561] occurs 29 times in the original matrix.
# Row 84 corresponding to class [560] occurs 72 times in the original matrix.
# Row 85 corresponding to class [559] occurs 172 times in the original matrix.
# Row 86 corresponding to class [558] occurs 15 times in the original matrix.
# Row 87 corresponding to class [557] occurs 16 times in the original matrix.
# Row 88 corresponding to class [556] occurs 7 times in the original matrix.
# Row 89 corresponding to class [555] occurs 89 times in the original matrix.
# Row 90 corresponding to class [554] occurs 150 times in the original matrix.
# Row 91 corresponding to class [553] occurs 8 times in the original matrix.
# Row 92 corresponding to class [552] occurs 21 times in the original matrix.
# Row 93 corresponding to class [551] occurs 20 times in the original matrix.
# Row 94 corresponding to class [550] occurs 40 times in the original matrix.
# Row 95 corresponding to class [549] occurs 7 times in the original matrix.
# Row 96 corresponding to class [548] occurs 34 times in the original matrix.
# Row 97 corresponding to class [547] occurs 12 times in the original matrix.
# Row 98 corresponding to class [546] occurs 81 times in the original matrix.
# Row 99 corresponding to class [545] occurs 126 times in the original matrix.
# Row 100 corresponding to class [543] occurs 16 times in the original matrix.
# Row 101 corresponding to class [542] occurs 16 times in the original matrix.
# Row 102 corresponding to class [541] occurs 8 times in the original matrix.
# Row 103 corresponding to class [540] occurs 8 times in the original matrix.
# Row 104 corresponding to class [539] occurs 140 times in the original matrix.
# Row 105 corresponding to class [538] occurs 141 times in the original matrix.
# Row 106 corresponding to class [537] occurs 104 times in the original matrix.
# Row 107 corresponding to class [536] occurs 78 times in the original matrix.
# Row 108 corresponding to class [535] occurs 158 times in the original matrix.
# Row 109 corresponding to class [534] occurs 13 times in the original matrix.
# Row 110 corresponding to class [533] occurs 159 times in the original matrix.
# Row 111 corresponding to class [532] occurs 64 times in the original matrix.
# Row 112 corresponding to class [531] occurs 205 times in the original matrix.
# Row 113 corresponding to class [530] occurs 109 times in the original matrix.
# Row 114 corresponding to class [529] occurs 38 times in the original matrix.
# Row 115 corresponding to class [527] occurs 61 times in the original matrix.
# Row 116 corresponding to class [526] occurs 96 times in the original matrix.
# Row 117 corresponding to class [525] occurs 448 times in the original matrix.
# Row 118 corresponding to class [523] occurs 120 times in the original matrix.
# Row 119 corresponding to class [522] occurs 154 times in the original matrix.
# Row 120 corresponding to class [521] occurs 94 times in the original matrix.
# Row 121 corresponding to class [520] occurs 186 times in the original matrix.
# Row 122 corresponding to class [519] occurs 68 times in the original matrix.
# Row 123 corresponding to class [518] occurs 151 times in the original matrix.
# Row 124 corresponding to class [517] occurs 46 times in the original matrix.
# Row 125 corresponding to class [516] occurs 38 times in the original matrix.
# Row 126 corresponding to class [515] occurs 16 times in the original matrix.
# Row 127 corresponding to class [514] occurs 73 times in the original matrix.
# Row 128 corresponding to class [513] occurs 32 times in the original matrix.
# Row 129 corresponding to class [512] occurs 152 times in the original matrix.
# Row 130 corresponding to class [511] occurs 68 times in the original matrix.
# Row 131 corresponding to class [510] occurs 26 times in the original matrix.
# Row 132 corresponding to class [509] occurs 52 times in the original matrix.
# Row 133 corresponding to class [508] occurs 18 times in the original matrix.
# Row 134 corresponding to class [507] occurs 8 times in the original matrix.
# Row 135 corresponding to class [506] occurs 15 times in the original matrix.
# Row 136 corresponding to class [505] occurs 32 times in the original matrix.
# Row 137 corresponding to class [504] occurs 235 times in the original matrix.
# Row 138 corresponding to class [503] occurs 12 times in the original matrix.
# Row 139 corresponding to class [502] occurs 294 times in the original matrix.
# Row 140 corresponding to class [501] occurs 7 times in the original matrix.
# Row 141 corresponding to class [500] occurs 43 times in the original matrix.
# Row 142 corresponding to class [498] occurs 14 times in the original matrix.
# Row 143 corresponding to class [497] occurs 82 times in the original matrix.
# Row 144 corresponding to class [496] occurs 6 times in the original matrix.
# Row 145 corresponding to class [495] occurs 140 times in the original matrix.
# Row 146 corresponding to class [494] occurs 400 times in the original matrix.
# Row 147 corresponding to class [493] occurs 167 times in the original matrix.
# Row 148 corresponding to class [492] occurs 35 times in the original matrix.
# Row 149 corresponding to class [491] occurs 162 times in the original matrix.
# Row 150 corresponding to class [490] occurs 185 times in the original matrix.
# Row 151 corresponding to class [489] occurs 31 times in the original matrix.
# Row 152 corresponding to class [488] occurs 157 times in the original matrix.
# Row 153 corresponding to class [487] occurs 6 times in the original matrix.
# Row 154 corresponding to class [486] occurs 143 times in the original matrix.
# Row 155 corresponding to class [485] occurs 72 times in the original matrix.
# Row 156 corresponding to class [484] occurs 14 times in the original matrix.
# Row 157 corresponding to class [483] occurs 4 times in the original matrix.
# Row 158 corresponding to class [482] occurs 82 times in the original matrix.
# Row 159 corresponding to class [481] occurs 90 times in the original matrix.
# Row 160 corresponding to class [480] occurs 326 times in the original matrix.
# Row 161 corresponding to class [478] occurs 149 times in the original matrix.
# Row 162 corresponding to class [477] occurs 33 times in the original matrix.
# Row 163 corresponding to class [476] occurs 95 times in the original matrix.
# Row 164 corresponding to class [475] occurs 25 times in the original matrix.
# Row 165 corresponding to class [474] occurs 98 times in the original matrix.
# Row 166 corresponding to class [473] occurs 81 times in the original matrix.
# Row 167 corresponding to class [472] occurs 9 times in the original matrix.
# Row 168 corresponding to class [471] occurs 10 times in the original matrix.
# Row 169 corresponding to class [470] occurs 14 times in the original matrix.
# Row 170 corresponding to class [469] occurs 30 times in the original matrix.
# Row 171 corresponding to class [468] occurs 85 times in the original matrix.
# Row 172 corresponding to class [467] occurs 16 times in the original matrix.
# Row 173 corresponding to class [466] occurs 43 times in the original matrix.
# Row 174 corresponding to class [465] occurs 19 times in the original matrix.
# Row 175 corresponding to class [464] occurs 9 times in the original matrix.
# Row 176 corresponding to class [463] occurs 31 times in the original matrix.
# Row 177 corresponding to class [462] occurs 3 times in the original matrix.
# Row 178 corresponding to class [461] occurs 9 times in the original matrix.
# Row 179 corresponding to class [460] occurs 12 times in the original matrix.
# Row 180 corresponding to class [459] occurs 48 times in the original matrix.
# Row 181 corresponding to class [458] occurs 288 times in the original matrix.
# Row 182 corresponding to class [457] occurs 165 times in the original matrix.
# Row 183 corresponding to class [456] occurs 245 times in the original matrix.
# Row 184 corresponding to class [455] occurs 5 times in the original matrix.
# Row 185 corresponding to class [454] occurs 26 times in the original matrix.
# Row 186 corresponding to class [453] occurs 17 times in the original matrix.
# Row 187 corresponding to class [450] occurs 220 times in the original matrix.
# Row 188 corresponding to class [449] occurs 16 times in the original matrix.
# Row 189 corresponding to class [448] occurs 45 times in the original matrix.
# Row 190 corresponding to class [447] occurs 25 times in the original matrix.
# Row 191 corresponding to class [446] occurs 52 times in the original matrix.
# Row 192 corresponding to class [445] occurs 30 times in the original matrix.
# Row 193 corresponding to class [444] occurs 9 times in the original matrix.
# Row 194 corresponding to class [443] occurs 378 times in the original matrix.
# Row 195 corresponding to class [442] occurs 19 times in the original matrix.
# Row 196 corresponding to class [441] occurs 18 times in the original matrix.
# Row 197 corresponding to class [440] occurs 214 times in the original matrix.
# Row 198 corresponding to class [439] occurs 100 times in the original matrix.
# Row 199 corresponding to class [438] occurs 369 times in the original matrix.
# Row 200 corresponding to class [437] occurs 4 times in the original matrix.
# Row 201 corresponding to class [436] occurs 23 times in the original matrix.
# Row 202 corresponding to class [435] occurs 36 times in the original matrix.
# Row 203 corresponding to class [434] occurs 74 times in the original matrix.
# Row 204 corresponding to class [433] occurs 83 times in the original matrix.
# Row 205 corresponding to class [432] occurs 197 times in the original matrix.
# Row 206 corresponding to class [431] occurs 31 times in the original matrix.
# Row 207 corresponding to class [430] occurs 18 times in the original matrix.
# Row 208 corresponding to class [429] occurs 10 times in the original matrix.
# Row 209 corresponding to class [428] occurs 14 times in the original matrix.
# Row 210 corresponding to class [427] occurs 143 times in the original matrix.
# Row 211 corresponding to class [426] occurs 40 times in the original matrix.
# Row 212 corresponding to class [425] occurs 16 times in the original matrix.
# Row 213 corresponding to class [424] occurs 177 times in the original matrix.
# Row 214 corresponding to class [423] occurs 9 times in the original matrix.
# Row 215 corresponding to class [422] occurs 73 times in the original matrix.
# Row 216 corresponding to class [421] occurs 55 times in the original matrix.
# Row 217 corresponding to class [420] occurs 308 times in the original matrix.
# Row 218 corresponding to class [419] occurs 59 times in the original matrix.
# Row 219 corresponding to class [418] occurs 41 times in the original matrix.
# Row 220 corresponding to class [417] occurs 56 times in the original matrix.
# Row 221 corresponding to class [416] occurs 249 times in the original matrix.
# Row 222 corresponding to class [415] occurs 51 times in the original matrix.
# Row 223 corresponding to class [413] occurs 130 times in the original matrix.
# Row 224 corresponding to class [412] occurs 54 times in the original matrix.
# Row 225 corresponding to class [411] occurs 43 times in the original matrix.
# Row 226 corresponding to class [410] occurs 198 times in the original matrix.
# Row 227 corresponding to class [409] occurs 84 times in the original matrix.
# Row 228 corresponding to class [408] occurs 102 times in the original matrix.
# Row 229 corresponding to class [407] occurs 70 times in the original matrix.
# Row 230 corresponding to class [406] occurs 5 times in the original matrix.
# Row 231 corresponding to class [405] occurs 28 times in the original matrix.
# Row 232 corresponding to class [404] occurs 2 times in the original matrix.
# Row 233 corresponding to class [403] occurs 53 times in the original matrix.
# Row 234 corresponding to class [402] occurs 66 times in the original matrix.
# Row 235 corresponding to class [401] occurs 156 times in the original matrix.
# Row 236 corresponding to class [400] occurs 28 times in the original matrix.
# Row 237 corresponding to class [399] occurs 44 times in the original matrix.
# Row 239 corresponding to class [395] occurs 108 times in the original matrix.
# Row 240 corresponding to class [394] occurs 32 times in the original matrix.
# Row 241 corresponding to class [393] occurs 14 times in the original matrix.
# Row 242 corresponding to class [392] occurs 7 times in the original matrix.
# Row 243 corresponding to class [391] occurs 29 times in the original matrix.
# Row 244 corresponding to class [390] occurs 49 times in the original matrix.
# Row 245 corresponding to class [389] occurs 110 times in the original matrix.
# Row 246 corresponding to class [387] occurs 106 times in the original matrix.
# Row 247 corresponding to class [386] occurs 3 times in the original matrix.
# Row 248 corresponding to class [385] occurs 19 times in the original matrix.
# Row 249 corresponding to class [384] occurs 9 times in the original matrix.
# Row 250 corresponding to class [383] occurs 22 times in the original matrix.
# Row 251 corresponding to class [382] occurs 44 times in the original matrix.
# Row 252 corresponding to class [381] occurs 22 times in the original matrix.
# Row 253 corresponding to class [380] occurs 91 times in the original matrix.
# Row 254 corresponding to class [377] occurs 664 times in the original matrix.
# Row 255 corresponding to class [376] occurs 12 times in the original matrix.
# Row 256 corresponding to class [375] occurs 53 times in the original matrix.
# Row 257 corresponding to class [374] occurs 29 times in the original matrix.
# Row 258 corresponding to class [373] occurs 6 times in the original matrix.
# Row 259 corresponding to class [372] occurs 30 times in the original matrix.
# Row 260 corresponding to class [371] occurs 37 times in the original matrix.
# Row 261 corresponding to class [370] occurs 4 times in the original matrix.
# Row 262 corresponding to class [369] occurs 5 times in the original matrix.
# Row 263 corresponding to class [368] occurs 23 times in the original matrix.
# Row 264 corresponding to class [367] occurs 5 times in the original matrix.
# Row 265 corresponding to class [366] occurs 41 times in the original matrix.
# Row 266 corresponding to class [365] occurs 43 times in the original matrix.
# Row 267 corresponding to class [364] occurs 63 times in the original matrix.
# Row 268 corresponding to class [363] occurs 122 times in the original matrix.
# Row 269 corresponding to class [362] occurs 434 times in the original matrix.
# Row 270 corresponding to class [361] occurs 9 times in the original matrix.
# Row 271 corresponding to class [360] occurs 48 times in the original matrix.
# Row 272 corresponding to class [359] occurs 60 times in the original matrix.
# Row 273 corresponding to class [358] occurs 37 times in the original matrix.
# Row 274 corresponding to class [357] occurs 374 times in the original matrix.
# Row 275 corresponding to class [356] occurs 58 times in the original matrix.
# Row 276 corresponding to class [355] occurs 110 times in the original matrix.
# Row 277 corresponding to class [354] occurs 33 times in the original matrix.
# Row 278 corresponding to class [352] occurs 244 times in the original matrix.
# Row 279 corresponding to class [351] occurs 3 times in the original matrix.
# Row 280 corresponding to class [350] occurs 121 times in the original matrix.
# Row 281 corresponding to class [349] occurs 176 times in the original matrix.
# Row 282 corresponding to class [348] occurs 21 times in the original matrix.
# Row 283 corresponding to class [347] occurs 117 times in the original matrix.
# Row 284 corresponding to class [346] occurs 10 times in the original matrix.
# Row 285 corresponding to class [345] occurs 5 times in the original matrix.
# Row 286 corresponding to class [344] occurs 255 times in the original matrix.
# Row 287 corresponding to class [343] occurs 23 times in the original matrix.
# Row 288 corresponding to class [342] occurs 17 times in the original matrix.
# Row 289 corresponding to class [341] occurs 63 times in the original matrix.
# Row 290 corresponding to class [340] occurs 8 times in the original matrix.
# Row 291 corresponding to class [339] occurs 226 times in the original matrix.
# Row 292 corresponding to class [338] occurs 71 times in the original matrix.
# Row 293 corresponding to class [337] occurs 16 times in the original matrix.
# Row 294 corresponding to class [336] occurs 522 times in the original matrix.
# Row 295 corresponding to class [335] occurs 15 times in the original matrix.
# Row 296 corresponding to class [334] occurs 12 times in the original matrix.
# Row 297 corresponding to class [333] occurs 10 times in the original matrix.
# Row 298 corresponding to class [332] occurs 10 times in the original matrix.
# Row 299 corresponding to class [331] occurs 28 times in the original matrix.
# Row 300 corresponding to class [330] occurs 372 times in the original matrix.
# Row 301 corresponding to class [329] occurs 14 times in the original matrix.
# Row 302 corresponding to class [328] occurs 16 times in the original matrix.
# Row 303 corresponding to class [327] occurs 141 times in the original matrix.
# Row 304 corresponding to class [322] occurs 198 times in the original matrix.
# Row 305 corresponding to class [321] occurs 46 times in the original matrix.
# Row 306 corresponding to class [320] occurs 49 times in the original matrix.
# Row 307 corresponding to class [319] occurs 44 times in the original matrix.
# Row 308 corresponding to class [318] occurs 125 times in the original matrix.
# Row 309 corresponding to class [317] occurs 14 times in the original matrix.
# Row 310 corresponding to class [316] occurs 50 times in the original matrix.
# Row 311 corresponding to class [315] occurs 25 times in the original matrix.
# Row 312 corresponding to class [314] occurs 270 times in the original matrix.
# Row 313 corresponding to class [313] occurs 27 times in the original matrix.
# Row 314 corresponding to class [312] occurs 641 times in the original matrix.
# Row 315 corresponding to class [311] occurs 79 times in the original matrix.
# Row 316 corresponding to class [310] occurs 16 times in the original matrix.
# Row 317 corresponding to class [309] occurs 221 times in the original matrix.
# Row 318 corresponding to class [308] occurs 5 times in the original matrix.
# Row 319 corresponding to class [307] occurs 65 times in the original matrix.
# Row 320 corresponding to class [306] occurs 37 times in the original matrix.
# Row 321 corresponding to class [305] occurs 60 times in the original matrix.
# Row 322 corresponding to class [304] occurs 19 times in the original matrix.
# Row 323 corresponding to class [303] occurs 7 times in the original matrix.
# Row 324 corresponding to class [302] occurs 28 times in the original matrix.
# Row 325 corresponding to class [301] occurs 13 times in the original matrix.
# Row 326 corresponding to class [300] occurs 11 times in the original matrix.
# Row 327 corresponding to class [299] occurs 144 times in the original matrix.
# Row 328 corresponding to class [298] occurs 91 times in the original matrix.
# Row 329 corresponding to class [297] occurs 32 times in the original matrix.
# Row 330 corresponding to class [296] occurs 52 times in the original matrix.
# Row 331 corresponding to class [295] occurs 400 times in the original matrix.
# Row 332 corresponding to class [294] occurs 34 times in the original matrix.
# Row 333 corresponding to class [293] occurs 99 times in the original matrix.
# Row 334 corresponding to class [292] occurs 16 times in the original matrix.
# Row 335 corresponding to class [291] occurs 7 times in the original matrix.
# Row 336 corresponding to class [290] occurs 5 times in the original matrix.
# Row 337 corresponding to class [289] occurs 35 times in the original matrix.
# Row 338 corresponding to class [288] occurs 1219 times in the original matrix.
# Row 339 corresponding to class [287] occurs 1186 times in the original matrix.
# Row 340 corresponding to class [286] occurs 113 times in the original matrix.
# Row 341 corresponding to class [285] occurs 7 times in the original matrix.
# Row 342 corresponding to class [284] occurs 666 times in the original matrix.
# Row 343 corresponding to class [283] occurs 3 times in the original matrix.
# Row 344 corresponding to class [282] occurs 1209 times in the original matrix.
# Row 345 corresponding to class [281] occurs 1334 times in the original matrix.
# Row 346 corresponding to class [280] occurs 1724 times in the original matrix.
# Row 347 corresponding to class [279] occurs 1198 times in the original matrix.
# Row 348 corresponding to class [278] occurs 27 times in the original matrix.
# Row 349 corresponding to class [277] occurs 73 times in the original matrix.
# Row 350 corresponding to class [276] occurs 136 times in the original matrix.
# Row 351 corresponding to class [275] occurs 5 times in the original matrix.
# Row 352 corresponding to class [274] occurs 555 times in the original matrix.
# Row 353 corresponding to class [273] occurs 17 times in the original matrix.
# Row 354 corresponding to class [272] occurs 185 times in the original matrix.
# Row 355 corresponding to class [271] occurs 49 times in the original matrix.
# Row 356 corresponding to class [270] occurs 57 times in the original matrix.
# Row 357 corresponding to class [269] occurs 203 times in the original matrix.
# Row 358 corresponding to class [268] occurs 55 times in the original matrix.
# Row 359 corresponding to class [267] occurs 110 times in the original matrix.
# Row 360 corresponding to class [266] occurs 34 times in the original matrix.
# Row 361 corresponding to class [265] occurs 12 times in the original matrix.
# Row 362 corresponding to class [264] occurs 49 times in the original matrix.
# Row 363 corresponding to class [263] occurs 45 times in the original matrix.
# Row 364 corresponding to class [262] occurs 6 times in the original matrix.
# Row 365 corresponding to class [261] occurs 1081 times in the original matrix.
# Row 366 corresponding to class [260] occurs 25 times in the original matrix.
# Row 367 corresponding to class [259] occurs 1106 times in the original matrix.
# Row 368 corresponding to class [258] occurs 18 times in the original matrix.
# Row 369 corresponding to class [257] occurs 470 times in the original matrix.
# Row 370 corresponding to class [256] occurs 80 times in the original matrix.
# Row 371 corresponding to class [255] occurs 121 times in the original matrix.
# Row 372 corresponding to class [254] occurs 14 times in the original matrix.
# Row 373 corresponding to class [253] occurs 60 times in the original matrix.
# Row 374 corresponding to class [252] occurs 19 times in the original matrix.
# Row 375 corresponding to class [251] occurs 2 times in the original matrix.
# Row 376 corresponding to class [249] occurs 200 times in the original matrix.
# Row 377 corresponding to class [248] occurs 344 times in the original matrix.
# Row 378 corresponding to class [247] occurs 37 times in the original matrix.
# Row 379 corresponding to class [246] occurs 51 times in the original matrix.
# Row 380 corresponding to class [245] occurs 90 times in the original matrix.
# Row 381 corresponding to class [244] occurs 265 times in the original matrix.
# Row 382 corresponding to class [243] occurs 59 times in the original matrix.
# Row 383 corresponding to class [242] occurs 35 times in the original matrix.
# Row 384 corresponding to class [241] occurs 141 times in the original matrix.
# Row 385 corresponding to class [240] occurs 148 times in the original matrix.
# Row 386 corresponding to class [239] occurs 317 times in the original matrix.
# Row 387 corresponding to class [238] occurs 52 times in the original matrix.
# Row 388 corresponding to class [237] occurs 27 times in the original matrix.
# Row 389 corresponding to class [236] occurs 508 times in the original matrix.
# Row 390 corresponding to class [235] occurs 70 times in the original matrix.
# Row 391 corresponding to class [234] occurs 562 times in the original matrix.
# Row 392 corresponding to class [233] occurs 331 times in the original matrix.
# Row 393 corresponding to class [232] occurs 4 times in the original matrix.
# Row 394 corresponding to class [231] occurs 5 times in the original matrix.
# Row 395 corresponding to class [230] occurs 30 times in the original matrix.
# Row 396 corresponding to class [228] occurs 34 times in the original matrix.
# Row 397 corresponding to class [226] occurs 127 times in the original matrix.
# Row 398 corresponding to class [225] occurs 2 times in the original matrix.
# Row 399 corresponding to class [224] occurs 96 times in the original matrix.
# Row 400 corresponding to class [223] occurs 8 times in the original matrix.
# Row 401 corresponding to class [222] occurs 102 times in the original matrix.
# Row 402 corresponding to class [221] occurs 14 times in the original matrix.
# Row 403 corresponding to class [220] occurs 37 times in the original matrix.
# Row 404 corresponding to class [219] occurs 99 times in the original matrix.
# Row 405 corresponding to class [218] occurs 2 times in the original matrix.
# Row 406 corresponding to class [217] occurs 32 times in the original matrix.
# Row 407 corresponding to class [216] occurs 457 times in the original matrix.
# Row 408 corresponding to class [215] occurs 110 times in the original matrix.
# Row 409 corresponding to class [214] occurs 78 times in the original matrix.
# Row 410 corresponding to class [213] occurs 117 times in the original matrix.
# Row 411 corresponding to class [212] occurs 40 times in the original matrix.
# Row 412 corresponding to class [211] occurs 47 times in the original matrix.
# Row 413 corresponding to class [210] occurs 122 times in the original matrix.
# Row 414 corresponding to class [209] occurs 47 times in the original matrix.
# Row 415 corresponding to class [208] occurs 47 times in the original matrix.
# Row 416 corresponding to class [207] occurs 570 times in the original matrix.
# Row 417 corresponding to class [206] occurs 9 times in the original matrix.
# Row 418 corresponding to class [204] occurs 190 times in the original matrix.
# Row 419 corresponding to class [203] occurs 2 times in the original matrix.
# Row 420 corresponding to class [202] occurs 78 times in the original matrix.
# Row 421 corresponding to class [201] occurs 12 times in the original matrix.
# Row 422 corresponding to class [200] occurs 119 times in the original matrix.
# Row 423 corresponding to class [199] occurs 82 times in the original matrix.
# Row 424 corresponding to class [198] occurs 204 times in the original matrix.
# Row 425 corresponding to class [197] occurs 14 times in the original matrix.
# Row 426 corresponding to class [195] occurs 12 times in the original matrix.
# Row 427 corresponding to class [194] occurs 118 times in the original matrix.
# Row 428 corresponding to class [192] occurs 13 times in the original matrix.
# Row 429 corresponding to class [191] occurs 71 times in the original matrix.
# Row 430 corresponding to class [190] occurs 10 times in the original matrix.
# Row 431 corresponding to class [189] occurs 5 times in the original matrix.
# Row 432 corresponding to class [188] occurs 3 times in the original matrix.
# Row 433 corresponding to class [187] occurs 21 times in the original matrix.
# Row 434 corresponding to class [186] occurs 88 times in the original matrix.
# Row 435 corresponding to class [185] occurs 12 times in the original matrix.
# Row 436 corresponding to class [184] occurs 373 times in the original matrix.
# Row 437 corresponding to class [183] occurs 37 times in the original matrix.
# Row 438 corresponding to class [182] occurs 18 times in the original matrix.
# Row 439 corresponding to class [181] occurs 22 times in the original matrix.
# Row 440 corresponding to class [180] occurs 40 times in the original matrix.
# Row 441 corresponding to class [179] occurs 413 times in the original matrix.
# Row 442 corresponding to class [178] occurs 3 times in the original matrix.
# Row 443 corresponding to class [177] occurs 50 times in the original matrix.
# Row 444 corresponding to class [175] occurs 32 times in the original matrix.
# Row 445 corresponding to class [174] occurs 24 times in the original matrix.
# Row 446 corresponding to class [173] occurs 68 times in the original matrix.
# Row 447 corresponding to class [172] occurs 196 times in the original matrix.
# Row 448 corresponding to class [171] occurs 13 times in the original matrix.
# Row 449 corresponding to class [169] occurs 51 times in the original matrix.
# Row 450 corresponding to class [168] occurs 45 times in the original matrix.
# Row 451 corresponding to class [167] occurs 23 times in the original matrix.
# Row 452 corresponding to class [166] occurs 139 times in the original matrix.
# Row 453 corresponding to class [165] occurs 4 times in the original matrix.
# Row 454 corresponding to class [164] occurs 24 times in the original matrix.
# Row 455 corresponding to class [163] occurs 15 times in the original matrix.
# Row 456 corresponding to class [162] occurs 127 times in the original matrix.
# Row 457 corresponding to class [161] occurs 19 times in the original matrix.
# Row 458 corresponding to class [160] occurs 57 times in the original matrix.
# Row 459 corresponding to class [159] occurs 32 times in the original matrix.
# Row 460 corresponding to class [158] occurs 12 times in the original matrix.
# Row 461 corresponding to class [157] occurs 18 times in the original matrix.
# Row 462 corresponding to class [156] occurs 90 times in the original matrix.
# Row 463 corresponding to class [154] occurs 209 times in the original matrix.
# Row 464 corresponding to class [153] occurs 508 times in the original matrix.
# Row 465 corresponding to class [152] occurs 54 times in the original matrix.
# Row 466 corresponding to class [151] occurs 9 times in the original matrix.
# Row 467 corresponding to class [150] occurs 24 times in the original matrix.
# Row 468 corresponding to class [149] occurs 107 times in the original matrix.
# Row 469 corresponding to class [148] occurs 1316 times in the original matrix.
# Row 470 corresponding to class [147] occurs 14 times in the original matrix.
# Row 471 corresponding to class [146] occurs 200 times in the original matrix.
# Row 472 corresponding to class [145] occurs 7 times in the original matrix.
# Row 473 corresponding to class [144] occurs 69 times in the original matrix.
# Row 474 corresponding to class [143] occurs 489 times in the original matrix.
# Row 475 corresponding to class [142] occurs 39 times in the original matrix.
# Row 476 corresponding to class [141] occurs 234 times in the original matrix.
# Row 477 corresponding to class [140] occurs 161 times in the original matrix.
# Row 478 corresponding to class [139] occurs 19 times in the original matrix.
# Row 479 corresponding to class [138] occurs 101 times in the original matrix.
# Row 480 corresponding to class [137] occurs 10 times in the original matrix.
# Row 481 corresponding to class [136] occurs 7 times in the original matrix.
# Row 482 corresponding to class [135] occurs 3 times in the original matrix.
# Row 483 corresponding to class [134] occurs 2 times in the original matrix.
# Row 484 corresponding to class [133] occurs 3 times in the original matrix.
# Row 485 corresponding to class [132] occurs 14 times in the original matrix.
# Row 486 corresponding to class [131] occurs 5 times in the original matrix.
# Row 487 corresponding to class [130] occurs 2 times in the original matrix.
# Row 488 corresponding to class [129] occurs 2 times in the original matrix.
# Row 489 corresponding to class [128] occurs 6 times in the original matrix.
# Row 490 corresponding to class [127] occurs 8 times in the original matrix.
# Row 491 corresponding to class [126] occurs 3 times in the original matrix.
# Row 492 corresponding to class [125] occurs 3 times in the original matrix.
# Row 493 corresponding to class [124] occurs 2 times in the original matrix.
# Row 494 corresponding to class [123] occurs 7 times in the original matrix.
# Row 495 corresponding to class [122] occurs 12 times in the original matrix.
# Row 496 corresponding to class [121] occurs 3 times in the original matrix.
# Row 497 corresponding to class [120] occurs 4 times in the original matrix.
# Row 498 corresponding to class [119] occurs 6 times in the original matrix.
# Row 499 corresponding to class [118] occurs 35 times in the original matrix.
# Row 500 corresponding to class [117] occurs 74 times in the original matrix.
# Row 501 corresponding to class [116] occurs 4 times in the original matrix.
# Row 502 corresponding to class [115] occurs 236 times in the original matrix.
# Row 503 corresponding to class [114] occurs 97 times in the original matrix.
# Row 504 corresponding to class [113] occurs 8 times in the original matrix.
# Row 505 corresponding to class [112] occurs 130 times in the original matrix.
# Row 506 corresponding to class [111] occurs 3 times in the original matrix.
# Row 507 corresponding to class [110] occurs 2 times in the original matrix.
# Row 508 corresponding to class [109] occurs 39 times in the original matrix.
# Row 509 corresponding to class [108] occurs 708 times in the original matrix.
# Row 510 corresponding to class [107] occurs 85 times in the original matrix.
# Row 511 corresponding to class [106] occurs 405 times in the original matrix.
# Row 512 corresponding to class [105] occurs 30 times in the original matrix.
# Row 513 corresponding to class [104] occurs 147 times in the original matrix.
# Row 514 corresponding to class [103] occurs 15 times in the original matrix.
# Row 515 corresponding to class [102] occurs 5 times in the original matrix.
# Row 516 corresponding to class [101] occurs 29 times in the original matrix.
# Row 517 corresponding to class [99] occurs 16 times in the original matrix.
# Row 518 corresponding to class [98] occurs 83 times in the original matrix.
# Row 519 corresponding to class [97] occurs 320 times in the original matrix.
# Row 520 corresponding to class [96] occurs 36 times in the original matrix.
# Row 521 corresponding to class [95] occurs 42 times in the original matrix.
# Row 522 corresponding to class [94] occurs 18 times in the original matrix.
# Row 523 corresponding to class [93] occurs 209 times in the original matrix.
# Row 524 corresponding to class [91] occurs 25 times in the original matrix.
# Row 525 corresponding to class [90] occurs 378 times in the original matrix.
# Row 526 corresponding to class [89] occurs 19 times in the original matrix.
# Row 527 corresponding to class [88] occurs 19 times in the original matrix.
# Row 528 corresponding to class [87] occurs 2 times in the original matrix.
# Row 529 corresponding to class [86] occurs 96 times in the original matrix.
# Row 530 corresponding to class [85] occurs 268 times in the original matrix.
# Row 531 corresponding to class [84] occurs 7 times in the original matrix.
# Row 532 corresponding to class [83] occurs 34 times in the original matrix.
# Row 533 corresponding to class [82] occurs 17 times in the original matrix.
# Row 534 corresponding to class [81] occurs 56 times in the original matrix.
# Row 535 corresponding to class [80] occurs 60 times in the original matrix.
# Row 536 corresponding to class [79] occurs 18 times in the original matrix.
# Row 537 corresponding to class [78] occurs 6 times in the original matrix.
# Row 538 corresponding to class [77] occurs 26 times in the original matrix.
# Row 539 corresponding to class [76] occurs 37 times in the original matrix.
# Row 540 corresponding to class [75] occurs 9 times in the original matrix.
# Row 541 corresponding to class [74] occurs 20 times in the original matrix.
# Row 542 corresponding to class [73] occurs 7 times in the original matrix.
# Row 543 corresponding to class [72] occurs 24 times in the original matrix.
# Row 544 corresponding to class [71] occurs 15 times in the original matrix.
# Row 545 corresponding to class [70] occurs 17 times in the original matrix.
# Row 546 corresponding to class [69] occurs 261 times in the original matrix.
# Row 547 corresponding to class [68] occurs 12 times in the original matrix.
# Row 548 corresponding to class [67] occurs 147 times in the original matrix.
# Row 549 corresponding to class [66] occurs 43 times in the original matrix.
# Row 550 corresponding to class [65] occurs 83 times in the original matrix.
# Row 551 corresponding to class [64] occurs 24 times in the original matrix.
# Row 552 corresponding to class [63] occurs 33 times in the original matrix.
# Row 553 corresponding to class [62] occurs 214 times in the original matrix.
# Row 554 corresponding to class [61] occurs 7 times in the original matrix.
# Row 555 corresponding to class [60] occurs 83 times in the original matrix.
# Row 556 corresponding to class [59] occurs 152 times in the original matrix.
# Row 557 corresponding to class [58] occurs 21 times in the original matrix.
# Row 558 corresponding to class [57] occurs 115 times in the original matrix.
# Row 559 corresponding to class [56] occurs 56 times in the original matrix.
# Row 560 corresponding to class [55] occurs 24 times in the original matrix.
# Row 561 corresponding to class [54] occurs 105 times in the original matrix.
# Row 562 corresponding to class [53] occurs 58 times in the original matrix.
# Row 563 corresponding to class [52] occurs 97 times in the original matrix.
# Row 564 corresponding to class [51] occurs 97 times in the original matrix.
# Row 565 corresponding to class [50] occurs 37 times in the original matrix.
# Row 566 corresponding to class [49] occurs 119 times in the original matrix.
# Row 567 corresponding to class [48] occurs 13 times in the original matrix.
# Row 568 corresponding to class [47] occurs 32 times in the original matrix.
# Row 569 corresponding to class [46] occurs 9 times in the original matrix.
# Row 570 corresponding to class [44] occurs 568 times in the original matrix.
# Row 571 corresponding to class [43] occurs 38 times in the original matrix.
# Row 572 corresponding to class [42] occurs 164 times in the original matrix.
# Row 573 corresponding to class [41] occurs 548 times in the original matrix.
# Row 574 corresponding to class [39] occurs 587 times in the original matrix.
# Row 575 corresponding to class [38] occurs 228 times in the original matrix.
# Row 576 corresponding to class [37] occurs 156 times in the original matrix.
# Row 577 corresponding to class [35] occurs 38 times in the original matrix.
# Row 578 corresponding to class [34] occurs 121 times in the original matrix.
# Row 579 corresponding to class [33] occurs 3 times in the original matrix.
# Row 580 corresponding to class [32] occurs 353 times in the original matrix.
# Row 581 corresponding to class [31] occurs 14 times in the original matrix.
# Row 582 corresponding to class [30] occurs 64 times in the original matrix.
# Row 583 corresponding to class [29] occurs 186 times in the original matrix.
# Row 584 corresponding to class [28] occurs 10 times in the original matrix.
# Row 585 corresponding to class [27] occurs 30 times in the original matrix.
# Row 586 corresponding to class [26] occurs 354 times in the original matrix.
# Row 587 corresponding to class [25] occurs 31 times in the original matrix.
# Row 588 corresponding to class [24] occurs 47 times in the original matrix.
# Row 589 corresponding to class [22] occurs 11 times in the original matrix.
# Row 590 corresponding to class [21] occurs 94 times in the original matrix.
# Row 591 corresponding to class [20] occurs 231 times in the original matrix.
# Row 592 corresponding to class [19] occurs 7 times in the original matrix.
# Row 593 corresponding to class [18] occurs 9 times in the original matrix.
# Row 594 corresponding to class [17] occurs 99 times in the original matrix.
# Row 595 corresponding to class [16] occurs 280 times in the original matrix.
# Row 596 corresponding to class [15] occurs 49 times in the original matrix.
# Row 597 corresponding to class [14] occurs 13 times in the original matrix.
# Row 598 corresponding to class [13] occurs 305 times in the original matrix.
# Row 599 corresponding to class [12] occurs 10 times in the original matrix.
# Row 600 corresponding to class [11] occurs 134 times in the original matrix.
# Row 601 corresponding to class [10] occurs 22 times in the original matrix.
# Row 602 corresponding to class [9] occurs 13 times in the original matrix.
# Row 603 corresponding to class [8] occurs 120 times in the original matrix.
# Row 604 corresponding to class [7] occurs 21 times in the original matrix.
# Row 605 corresponding to class [6] occurs 56 times in the original matrix.
# Row 606 corresponding to class [2] occurs 273 times in the original matrix.
# Row 607 corresponding to class [1] occurs 85 times in the original matrix.
# Row 608 corresponding to class [0] occurs 8 times in the original matrix.
# Class 652 - Training: 78, Validation: 26, Test: 26
# Class 651 - Training: 82, Validation: 27, Test: 28
# Class 650 - Training: 97, Validation: 32, Test: 33
# Class 649 - Training: 138, Validation: 46, Test: 47
# Class 648 - Training: 168, Validation: 56, Test: 57
# Class 647 - Training: 189, Validation: 63, Test: 64
# Class 646 - Training: 210, Validation: 70, Test: 71
# Class 645 - Training: 696, Validation: 232, Test: 234
# Class 644 - Training: 699, Validation: 233, Test: 235
# Class 643 - Training: 963, Validation: 321, Test: 323
# Class 642 - Training: 978, Validation: 326, Test: 329
# Class 641 - Training: 984, Validation: 328, Test: 331
# Class 640 - Training: 991, Validation: 331, Test: 334
# Class 639 - Training: 1022, Validation: 342, Test: 345
# Class 638 - Training: 1037, Validation: 347, Test: 351
# Class 637 - Training: 1202, Validation: 402, Test: 407
# Class 636 - Training: 1214, Validation: 406, Test: 412
# Class 635 - Training: 1224, Validation: 410, Test: 416
# Class 634 - Training: 1231, Validation: 413, Test: 419
# Class 633 - Training: 1324, Validation: 444, Test: 450
# Class 632 - Training: 1784, Validation: 598, Test: 604
# Class 631 - Training: 1818, Validation: 609, Test: 616
# Class 630 - Training: 1827, Validation: 612, Test: 619
# Class 629 - Training: 1845, Validation: 618, Test: 626
# ...
# Class 286 - Training: 22295, Validation: 7483, Test: 7609
# Class 285 - Training: 22299, Validation: 7484, Test: 7611
# Class 284 - Training: 22698, Validation: 7617, Test: 7745
# Class 283 - Training: 22699, Validation: 7618, Test: 7746
# Class 282 - Training: 23424, Validation: 7860, Test: 7988
# Class 281 - Training: 24224, Validation: 8127, Test: 8255
# Class 280 - Training: 25258, Validation: 8472, Test: 8600
# Class 279 - Training: 25976, Validation: 8712, Test: 8840
# Class 278 - Training: 25992, Validation: 8717, Test: 8846
